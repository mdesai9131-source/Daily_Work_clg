# %%
import pandas as pd
import numpy as np

# %%
data = {
    "p_id": [101, 102, 103, 104],
    "p_name": ["QWE", "SDF", "RTY", "RFV"],
    "Sales": [5000, 8000, 4000, 6000],
    "Amount": [20000, 78000, 45000, 96000],
}
df = pd.DataFrame(data)
df
# Out:
#    p_id p_name  Sales  Amount
# 0   101    QWE   5000   20000
# 1   102    SDF   8000   78000
# 2   103    RTY   4000   45000
# 3   104    RFV   6000   96000

# %%
df.loc[0] # First row display
# Out:
# p_id        101
# p_name      QWE
# Sales      5000
# Amount    20000
# Name: 0, dtype: object

# %%
df.loc[0, "Sales"] # 0 Row and only sales data
# Out:
# 5000

# %%
df.loc[:, ["p_name", "Sales"]] # all Row selected Columns
# Out:
#   p_name  Sales
# 0    QWE   5000
# 1    SDF   8000
# 2    RTY   4000
# 3    RFV   6000

# %%
df.loc[1:3] # 1 to 3 row display
# Out:
#    p_id p_name  Sales  Amount
# 1   102    SDF   8000   78000
# 2   103    RTY   4000   45000
# 3   104    RFV   6000   96000

# %%
df.loc[1:3, ["p_id", "Amount"]] # 1 to 3 row and selected Columns
# Out:
#    p_id  Amount
# 1   102   78000
# 2   103   45000
# 3   104   96000

# %%
df.iloc[0, 3]
# Out:
# 20000

# %%
df.iloc[:, [2, 3]]
# Out:
#    Sales  Amount
# 0   5000   20000
# 1   8000   78000
# 2   4000   45000
# 3   6000   96000

# %%
df.iloc[1:3]
# Out:
#    p_id p_name  Sales  Amount
# 1   102    SDF   8000   78000
# 2   103    RTY   4000   45000

# %%
df.iloc[1:4]
# Out:
#    p_id p_name  Sales  Amount
# 1   102    SDF   8000   78000
# 2   103    RTY   4000   45000
# 3   104    RFV   6000   96000
